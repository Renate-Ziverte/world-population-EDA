# %%
#import sll relevent libraries - please note, was not able to download seaborn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#download the data set and display first 5 rows of the dataset
df = pd.read_csv("world_population_data.csv")


df.head()
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 population  1980 population  1970 population  area (km²)  \
# ...

# %%
#show the shape (rows, columns) of the data set
df.shape
# Out:
# (234, 17)

# %%
#show column names
df.columns
# Out:
# Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')

# %%
#gain an overview of the data set including data  types& missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              234 non-null    int64
#  1   cca3              234 non-null    object
#  2   country           234 non-null    object
#  3   continent         234 non-null    object
#  4   2023 population   234 non-null    int64
#  5   2022 population   234 non-null    int64
#  6   2020 population   234 non-null    int64
#  7   2015 population   234 non-null    int64
#  8   2010 population   234 non-null    int64
#  9   2000 population   234 non-null    int64
#  10  1990 population   234 non-null    int64
#  11  1980 population   234 non-null    int64
#  12  1970 population   234 non-null    int64
#  13  area (km²)        234 non-null    float64
#  14  density (km²)     234 non-null    int64
#  15  growth rate       234 non-null    object
# ...

# %%
# Check data types of columns
print(df.dtypes)
# Out:
# rank                  int64
# cca3                 object
# country              object
# continent            object
# 2023 population       int64
# 2022 population       int64
# 2020 population       int64
# 2015 population       int64
# 2010 population       int64
# 2000 population       int64
# 1990 population       int64
# 1980 population       int64
# 1970 population       int64
# area (km²)          float64
# density (km²)         int64
# growth rate          object
# world percentage     object
# dtype: object

# %%
df.describe()
# Out:
#              rank  2023 population  2022 population  2020 population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.437442e+07     3.407441e+07     3.350107e+07
# std     67.694165     1.373864e+08     1.367664e+08     1.355899e+08
# min      1.000000     5.180000e+02     5.100000e+02     5.200000e+02
# 25%     59.250000     4.225982e+05     4.197385e+05     4.152845e+05
# 50%    117.500000     5.643895e+06     5.559944e+06     5.493074e+06
# 75%    175.750000     2.324537e+07     2.247650e+07     2.144798e+07
# max    234.000000     1.428628e+09     1.425887e+09     1.424930e+09
#
#        2015 population  2010 population  2000 population  1990 population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      3.172996e+07     2.984524e+07     2.626947e+07     2.271022e+07
# std       1.304050e+08     1.242185e+08     1.116982e+08     9.783217e+07
# ...

# %%
#display the count of countries per continent in this data set
value_counts = df['continent'].value_counts()
print(value_counts)
# Out:
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: continent, dtype: int64

# %%
#check for missing data 
#it appears there are no missing values in this data set
df.isna().sum()
# Out:
# rank                0
# cca3                0
# country             0
# continent           0
# 2023 population     0
# 2022 population     0
# 2020 population     0
# 2015 population     0
# 2010 population     0
# 2000 population     0
# 1990 population     0
# 1980 population     0
# 1970 population     0
# area (km²)          0
# density (km²)       0
# growth rate         0
# world percentage    0
# dtype: int64

# %%
# Create a bar plot for the distribution of countries across continents
value_counts = df['continent'].value_counts()

value_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Countries Across Continents')
plt.xlabel('Continent')
plt.ylabel('Number of Countries')
plt.show()

# %%
# Create a pie chart that shows world population distribution accross continents in 2023

population_by_continent = df.groupby('continent')['2023 population'].sum()

population_by_continent.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightgreen', 'lightcoral', 'gold', 'red', 'purple'])
plt.title('World Population Distribution by Continent in 2023')
plt.show()

# %%
# Create a bar plot for top 10 countries by population in 2023

top_countries_2023 = df.nlargest(10, '2023 population')

top_countries_2023.plot(x='country', y='2023 population', kind='bar', color='yellow')
plt.title('Top 10 Countries by Population in 2023')
plt.xlabel('Country')
plt.ylabel('Population in billions')
plt.show()

# %%
# Bar plot for top 10 countries by population in 2023 with Matplotlib
plt.figure(figsize=(10, 6))
plt.barh(top_countries_2023['country'], top_countries_2023['2023 population'], color='skyblue')
plt.title('Top 10 Countries by Population in 2023')
plt.xlabel('Population in billions')
plt.ylabel('Country')
plt.show()

# %%
#Create a choropleth map to visualize world population distribution by country
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the world map GeoDataFrame
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge the world map with the population data
merged_data = world.merge(df, how='left', left_on='iso_a3', right_on='cca3')

# Plot the choropleth map
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

merged_data.plot(column='2023 population', ax=ax, legend=True,
                 legend_kwds={'label': "Population by Country",
                              'orientation': "horizontal"})

plt.title('World Population Distribution by Country (2023)')
plt.show()

# %%
# Summary statistics for population density
density_stats = df.groupby('continent')['density (km²)'].describe()
print(density_stats)
# Out:
#                count         mean          std  min    25%    50%     75%  \
# continent
# Africa          57.0   131.666667   177.829406  2.0  28.00   70.0  148.00
# Asia            50.0  1005.460000  3320.378447  2.0  74.75  131.0  384.00
# Europe          50.0   669.540000  2624.564727  4.0  63.00  110.0  234.25
# North America   40.0   274.300000   284.300599  0.0  64.50  224.5  335.75
# Oceania         23.0   133.217391   151.060481  3.0  26.50   81.0  177.00
# South America   14.0    22.071429    19.679995  0.0   5.75   18.5   26.75
#
#                    max
# continent
# Africa           898.0
# Asia           21403.0
# Europe         18149.0
# North America   1301.0
# Oceania          639.0
# South America     73.0

# %%
import matplotlib.pyplot as plt

# Bar plot of population sizes by continent
plt.figure(figsize=(12, 8))
plt.bar(df['continent'], df['2023 population'], color='skyblue')
plt.title('Population Sizes by Continent (2023)')
plt.xlabel('Continent')
plt.ylabel('Population in bl')
plt.show()

# %%
# Identify the top countries with the largest populations in 2023
top_countries_2023 = df.nlargest(10, '2023 population')

print("Top Countries with the Largest Populations in 2023:")
print(top_countries_2023[['country', '2023 population']])
# Out:
# Top Countries with the Largest Populations in 2023:
#          country  2023 population
# 0          India       1428627663
# 1          China       1425671352
# 2  United States        339996563
# 3      Indonesia        277534122
# 4       Pakistan        240485658
# 5        Nigeria        223804632
# 6         Brazil        216422446
# 7     Bangladesh        172954319
# 8         Russia        144444359
# 9         Mexico        128455567

# %%
import matplotlib.pyplot as plt

# Identify the top countries with the largest populations in 2023
top_countries_2023 = df.nlargest(10, '2023 population')

# Bar plot for the top countries
plt.figure(figsize=(12, 8))
plt.bar(top_countries_2023['country'], top_countries_2023['2023 population'], color='skyblue')
plt.title('Top Countries with the Largest Populations in 2023')
plt.xlabel('Country')
plt.ylabel('Population in bl')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import matplotlib.pyplot as plt

# Specify the country for analysis
selected_country = 'Latvia'

# Extract relevant columns for the selected country
projections_columns = ['country', '2023 population', '2022 population', '2020 population', '2015 population', '2010 population', '2000 population', '1990 population', '1980 population', '1970 population']
selected_country_projections = df[df['country'] == selected_country][projections_columns]

# Set 'country' as the index for easier plotting
selected_country_projections.set_index('country', inplace=True)

# Plot line chart for population projections over time for the selected country
plt.figure(figsize=(15, 8))
selected_country_projections.T.plot(marker='o', figsize=(15, 8))
plt.title(f'Population Projections Over Time for {selected_country}')
plt.xlabel('Year')
plt.ylabel('Population in million')
plt.legend(title='Year', bbox_to_anchor=(1, 1))

# Reverse the values on the x-axis
plt.gca().invert_xaxis()

plt.show()
